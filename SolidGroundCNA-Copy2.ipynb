# %%
import pandas as pd

# %%
import numpy as np

# %%
import plotly.express as px
import matplotlib.pyplot as plt
from statsmodels.graphics.mosaicplot import mosaic

# %%
schema_df = pd.read_excel('Solid_ground_data/CNA_schema.xlsx', index_col='Column')

# %%
df = pd.read_excel('Solid_ground_data/CNA1.xlsx', sheet_name='data')

# %%
df
# Out:
#        ID                  Language  imp_access_jobs_etc           imp_dental  \
# 0       1  English (United States)‎  Extremely Important  Extremely Important
# 1       2  English (United States)‎  Extremely Important  Extremely Important
# 2       4  English (United States)‎  Extremely Important       Very Important
# 3       5  English (United States)‎       Very Important       Very Important
# 4       6  English (United States)‎   Somewhat Important  Extremely Important
# ..    ...                       ...                  ...                  ...
# 222  1218  English (United States)‎           Don't Know  Extremely Important
# 223  1219  English (United States)‎           Don't Know       Very Important
# 224  1220  English (United States)‎       Very Important       Very Important
# 225  1221  English (United States)‎  Extremely Important  Extremely Important
# 226  1222  English (United States)‎   Somewhat Important       Very Important
#
# ...

# %%
df.shape # size of data
# Out:
# (227, 78)

# %%
pd.set_option('display.max_columns', 86)
pd.set_option('display.max_rows', 227)

# %%
schema_df.sort_index(inplace=True) # sort schema alphabetically

# %%
schema_df
# Out:
#                                                               OriginalLabel  \
# Column
# ID                                                                       ID
# Language                                                           Language
# access_food               Do you have access to food that meets your nee...
# age                                                       What is your age?
# borrowed_money                        Borrowed money from friends or family
# check_resouces            Below is a list of housing resources available...
# circumstances_job         Below is a list of circumstances which may mak...
# community_emp_inc         What do you want us to know about employment a...
# dental_care               Dental Care: Please check the barriers you've ...
# describe_housing                What best describes your housing situation?
# difficulty_job            Has it been hard to get or keep a job for you ...
# ...

# %%
schema_df.shape # size of data
# Out:
# (78, 2)

# %%
df.columns # list of column variables
# Out:
# Index(['ID', 'Language', 'imp_access_jobs_etc', 'imp_dental', 'imp_medical',
#        'imp_basic_ed', 'imp_childcare', 'imp_dom_viol_counseling',
#        'imp_drug_counseling', 'imp_food', 'imp_help_elec_bills', 'imp_life',
#        'imp_housing', 'imp_legal', 'imp_mental', 'imp_technology',
#        'imp_transportation', 'ease_access_jobs_etc', 'ease_dental',
#        'ease_medical', 'ease_basic_ed', 'ease_childcare',
#        'ease_dom_viol_counseling', 'ease_drug_counseling', 'ease_food',
#        'ease_help_elec_bills', 'ease_life', 'ease_housing', 'ease_legal',
#        'ease_mental', 'ease_technology', 'ease_transportation',
#        'describe_housing ', 'income_on_housing', 'check_resouces', 'housing',
#        'hungry', 'access_food', 'prevents_food', 'food_services', 'physical',
#        'mental', 'medical_care', 'dental_care', 'mental_services',
#        'presc_drugs', 'difficulty_job', 'circumstances_job', 'employment',
# ...

# %%
df['gender'].value_counts() # frequency count of each element in a specified column
# Out:
# gender
# Female;                                                                                                                                 146
# Male;                                                                                                                                    74
# A gender other than singularly female or male (e.g., non-binary, genderfluid, agender, Two Spirit, or a culturally specific gender);      4
# Name: count, dtype: int64

# %%
df['gender'].value_counts(normalize=True) # proportion of each element in the column
# Out:
# gender
# Female;                                                                                                                                 0.651786
# Male;                                                                                                                                   0.330357
# A gender other than singularly female or male (e.g., non-binary, genderfluid, agender, Two Spirit, or a culturally specific gender);    0.017857
# Name: proportion, dtype: float64

# %%
schema_df.loc['imp_medical'] # See meaning of variable using schema
# Out:
# OriginalLabel                              Affordable medical care
# QuestionText     On a scale of 1 to 4, how important is this se...
# Name: imp_medical, dtype: object

# %%
schema_df.loc['imp_medical','QuestionText'] # See full original survey question
# Out:
# "On a scale of 1 to 4, how important is this service to your household. Options: 1 - Not important, 2 - Somewhat important, 3 - Very important, 4 - Extremely important, don't know "

# %%
filt = (df['gender'] == 'Male;') # gives you part of data containing only the rows where the specified column has the specified entry

# %%
df[filt]
# Out:
#        ID                  Language  imp_access_jobs_etc           imp_dental  \
# 8      10  English (United States)‎  Extremely Important       Very Important
# 13     15  English (United States)‎  Extremely Important  Extremely Important
# 20     23  English (United States)‎       Very Important  Extremely Important
# 24     27  English (United States)‎  Extremely Important  Extremely Important
# 29     35  English (United States)‎  Extremely Important       Very Important
# 30     36  English (United States)‎   Somewhat Important  Extremely Important
# 32     49  English (United States)‎       Very Important  Extremely Important
# 36     64  English (United States)‎   Somewhat Important       Very Important
# 39    121  English (United States)‎       Very Important       Very Important
# 41    132  English (United States)‎  Extremely Important       Very Important
# 42    133  English (United States)‎  Extremely Important       Very Important
# ...

# %%
filt2 = df['food_services'].str.contains('Food Bank/ Pantry', na=False) # for "select all that apply" questions. Finds rows that include specified entry in a specified column

# %%
num = df.loc[filt2, 'food_services'] # creates a variable of values in the column that are filtered. The filter finds the entries where there is a specified substring

# %%
len(num) # counts rows where condition filt2 is true, indicating number of occurences of the entry(substring) in the column
# Out:
# 96

# %%
num # prints the column that statisifes the filter
# Out:
# 1                                     Food Bank/ Pantry;
# 3       Food Bank/ Pantry;Reduced-price meals at school;
# 4      EBT/ SNAP (Food Stamps);Food Bank/ Pantry;Free...
# 5                                     Food Bank/ Pantry;
# 7      EBT/ SNAP (Food Stamps);Food Bank/ Pantry;Fres...
# 8                                     Food Bank/ Pantry;
# 12                        Food Bank/ Pantry;Fresh Bucks;
# 14                           Churches;Food Bank/ Pantry;
# 16     Churches;EBT/ SNAP (Food Stamps);Food Bank/ Pa...
# 17     EBT/ SNAP (Food Stamps);Food Bank/ Pantry;WIC ...
# 19                                    Food Bank/ Pantry;
# 20               Churches;Food Bank/ Pantry;Fresh Bucks;
# 22     EBT/ SNAP (Food Stamps);Food Bank/ Pantry;Fres...
# 23                                    Food Bank/ Pantry;
# 24                Food Bank/ Pantry;Senior Center Meals;
# 26                           Food Bank/ Pantry;Churches;
# ...

# %%
df['race'].value_counts() #counts occurences of an entry in specified column
# Out:
# race
# White;                                                                                    110
# African American or Black ;                                                                46
# Asian;                                                                                     21
# Hispanic or Latino/a/x;                                                                    12
# Native American or Alaskan Native ;                                                        10
# Hispanic or Latino/a/x;White;                                                               3
# Native Hawaiian / Pacific Islander;                                                         3
# Native American or Alaskan Native ;White;                                                   3
# African American or Black ;White;                                                           2
# White;Asian;                                                                                2
# ...

# %%
race_grp = df.groupby(['race']) # each group corresponds to a unique value in the specified column

# %%
race_grp.get_group('White;') # retrieves the group of rows from the grouped DataFrame race_grp where the column has a specified entry
# Out:
#        ID                  Language  imp_access_jobs_etc           imp_dental  \
# 0       1  English (United States)‎  Extremely Important  Extremely Important
# 2       4  English (United States)‎  Extremely Important       Very Important
# 4       6  English (United States)‎   Somewhat Important  Extremely Important
# 8      10  English (United States)‎  Extremely Important       Very Important
# 10     12  English (United States)‎  Extremely Important  Extremely Important
# 11     13  English (United States)‎  Extremely Important  Extremely Important
# 12     14  English (United States)‎  Extremely Important  Extremely Important
# 13     15  English (United States)‎  Extremely Important  Extremely Important
# 15     18  English (United States)‎  Extremely Important  Extremely Important
# 18     21  English (United States)‎  Extremely Important       Very Important
# 25     28  English (United States)‎        Not Important        Not Important
# ...

# %%
race_grp['hungry'].value_counts() # calculates the value counts for the specified column within each group of the race_grp object.
# Out:
# race                                                                                    hungry
# 2 or more Native American ;                                                             Yes            1
# African American or Black ;                                                             No            29
#                                                                                         Yes           14
#                                                                                         Don't know     3
# African American or Black ;White;                                                       Yes            1
#                                                                                         No             1
# Asian;                                                                                  Yes           11
#                                                                                         No            10
# ...

# %%
race_grp['hungry'].value_counts(normalize=True) #calculates the relative frequency of each unique value in each group
# Out:
# race                                                                                    hungry
# 2 or more Native American ;                                                             Yes           1.000000
# African American or Black ;                                                             No            0.630435
#                                                                                         Yes           0.304348
#                                                                                         Don't know    0.065217
# African American or Black ;White;                                                       Yes           0.500000
#                                                                                         No            0.500000
# Asian;                                                                                  Yes           0.523810
# ...

# %%
race_grp['food_services'].apply(lambda x: x.str.contains('Food Bank/ Pantry').sum()) # for select all that apply type answers. Counts frequency of entry in each group
# Out:
# race
# 2 or more Native American ;                                                                1
# African American or Black ;                                                               18
# African American or Black ;White;                                                          2
# Asian;                                                                                     2
# Asian;White;                                                                               1
# Hispanic or Latino/a/x;                                                                    8
# Hispanic or Latino/a/x;Native American or Alaskan Native ;White;                           0
# Hispanic or Latino/a/x;White;                                                              1
# Human;                                                                                     1
# Mixed race;                                                                                0
# ...
